# %% [markdown]
# # To run the Semstyle project

# %% [markdown]
# Change the "Runtime Type" as "GPU"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install colabcode
# Out:
# ...
#      |████████████████████████████████| 747kB 15.2MB/s
# ...
#      |████████████████████████████████| 8.3MB 20.9MB/s
# ...
#      |████████████████████████████████| 51kB 7.2MB/s
# ...
#      |████████████████████████████████| 389kB 49.5MB/s
# ...
#      |████████████████████████████████| 51kB 6.8MB/s
# ...
#      |████████████████████████████████| 430kB 43.1MB/s
# ...
#      |████████████████████████████████| 61kB 8.9MB/s
# ...
#      |████████████████████████████████| 71kB 9.1MB/s
# ...
#      |████████████████████████████████| 81kB 10.8MB/s
# ...
#      |████████████████████████████████| 122kB 60.7MB/s
# ...
#      |████████████████████████████████| 61kB 8.9MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.0.5-cp37-none-any.whl size=19246 sha256=d0d3b11a9f22d766c5b666b87a9e73fef22987aa372a7bf8a993861fa33be8df
#   Stored in directory: /root/.cache/pip/wheels/0c/13/64/5ebbcc22eaf53fdf5766b397c1fb17c83f5775fdccf0ea1b88
# Successfully built pyngrok
# ...

# %%
from colabcode import ColabCode

# %% [markdown]
# After running the below cell, click on the link displayed
#
# Example: click on the link which is like "http://5fd63a26cd7b.ngrok.io"
# to Run code server on Google Colab and enter the password mentioned below.

# %%
ColabCode(port=7000, password="pswd")
# Out:
# Code Server can be accessed on: NgrokTunnel: "http://6f211ade533a.ngrok.io" -> "http://localhost:7000"
# [2021-05-13T01:15:53.852Z] info  code-server 3.7.4 11f53784c58f68e7f4c5b3b8dae9407caa41725b
# [2021-05-13T01:15:53.853Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-05-13T01:15:53.864Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-05-13T01:15:53.864Z] info  HTTP server listening on http://127.0.0.1:7000
# [2021-05-13T01:15:53.864Z] info    - Authentication is enabled
# [2021-05-13T01:15:53.864Z] info      - Using password from $PASSWORD
# [2021-05-13T01:15:53.864Z] info    - Not serving HTTPS

# %% [markdown]
# Then open the folder in which the project is stored
# (/content/drive/Shareddrive/Semstyle/Semstyle)
#
# then Open the terminal and enter
#
# ```python img_to_text.py --testfolder testimg_folder``` for testing on images in the folder testimg_folder
#
# or
#
# ```python img_to_text.py --train``` for training

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# #Training

# %%
# !python /content/drive/Shareddrives/Semstyle/Semstyle/img_to_text.py --train
# Out:
# tcmalloc: large alloc 4888584192 bytes == 0x55a5fc3a0000 @  0x7f6fae2f21e7 0x7f6f5a12446e 0x7f6f5a174c7b 0x7f6f5a177e83 0x7f6f5a17807b 0x7f6f5a219761 0x55a592511cc0 0x55a592511a50 0x55a592585be0 0x55a5925804ae 0x55a5925133ea 0x55a59258232a 0x55a59251330a 0x55a5925813b5 0x55a59251330a 0x55a5925813b5 0x55a5925804ae 0x55a5925801b3 0x55a59264a182 0x55a59264a4fd 0x55a59264a3a6 0x55a592621723 0x55a5926213cc 0x7f6fad0dcbf7 0x55a5926212aa
# tcmalloc: large alloc 4888584192 bytes == 0x55a7571ea000 @  0x7f6fae2d4b6b 0x7f6fae2f4379 0x7f6f5aa2d25e 0x7f6f5aa2e9d2 0x7f6f982f5853 0x7f6f97b7d043 0x7f6f9807e7d7 0x7f6f9804dda0 0x7f6f97ea8679 0x7f6f97b6d85a 0x7f6f9817c1f3 0x7f6f982c189b 0x7f6fa9871158 0x7f6fa98757a0 0x7f6fa9472c21 0x55a592511d54 0x55a592511a50 0x55a592586105 0x55a59251330a 0x55a5925813b5 0x55a59251330a 0x55a5925813b5 0x55a5925804ae 0x55a5925801b3 0x55a59264a182 0x55a59264a4fd 0x55a59264a3a6 0x55a592621723 0x55a5926213cc 0x7f6fad0dcbf7 0x55a5926212aa
# ^C

# %% [markdown]
# # **Testing**

# %%
from IPython.display import Image, display

# %%
display(Image('/content/drive/Shareddrives/Semstyle/Semstyle/test_image/000000581738.jpg'))
display(Image('/content/drive/Shareddrives/Semstyle/Semstyle/test_image/000000581739.jpg'))
display(Image('/content/drive/Shareddrives/Semstyle/Semstyle/test_image/COCO_train2014_000000581744.jpg'))
display(Image('/content/drive/Shareddrives/Semstyle/Semstyle/test_image/COCO_train2014_000000581789.jpg'))
display(Image('/content/drive/Shareddrives/Semstyle/Semstyle/test_image/COCO_train2014_000000581795.jpg'))
display(Image('/content/drive/Shareddrives/Semstyle/Semstyle/test_image/COCO_train2014_000000581797.jpg'))

# %%
# !python /content/drive/Shareddrives/Semstyle/Semstyle/img_to_text.py --test_folder /content/drive/Shareddrives/Semstyle/Semstyle/test_image
# Out:
# FN : /content/drive/Shareddrives/Semstyle/Semstyle/test_image/000000581738.jpg
# DET: busNOUNNOUNNOUN FRAMENETBringing streetNOUNNOUNNOUN ROMANCETOKEN
# ROM: the bus flew down the street .
#
# FN : /content/drive/Shareddrives/Semstyle/Semstyle/test_image/000000581739.jpg
# DET: flowerNOUNNOUNNOUN vaseNOUNNOUNNOUN ROMANCETOKEN
# ROM: i was n't sure i could n't bear to see the flowers in the vase .
#
# FN : /content/drive/Shareddrives/Semstyle/Semstyle/test_image/COCO_train2014_000000581744.jpg
# DET: computerNOUNNOUNNOUN deskNOUNNOUNNOUN ROMANCETOKEN
# ROM: i sat up at the computer desk .
#
# FN : /content/drive/Shareddrives/Semstyle/Semstyle/test_image/COCO_train2014_000000581789.jpg
# DET: manNOUNNOUNNOUN FRAMENETPosture frontNOUNNOUNNOUN planeNOUNNOUNNOUN ROMANCETOKEN
# ROM: the man standing in front of the plane .
#
# FN : /content/drive/Shareddrives/Semstyle/Semstyle/test_image/COCO_train2014_000000581795.jpg
# DET: manNOUNNOUNNOUN horseNOUNNOUNNOUN ROMANCETOKEN
# ...
